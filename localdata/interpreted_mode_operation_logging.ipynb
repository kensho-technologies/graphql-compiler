# %%
from abc import ABCMeta, abstractmethod
from collections import namedtuple
from itertools import chain, repeat
from pprint import pformat, pprint
from typing import (
    AbstractSet, Any, Callable, Collection, Dict, Generator, Generic, Iterable, List, Mapping,
    NamedTuple, Optional, Tuple, TypeVar, Union
)

from graphql import GraphQLList, GraphQLString, parse
from graphql.utilities.build_ast_schema import build_ast_schema
from graphql_compiler.compiler.blocks import (
    Backtrack, CoerceType, ConstructResult, EndOptional, Filter, GlobalOperationsStart, 
    MarkLocation, Recurse, QueryRoot, Traverse
)
from graphql_compiler.compiler.compiler_entities import BasicBlock, Expression
from graphql_compiler.compiler.expressions import (
    BinaryComposition, ContextField, ContextFieldExistence, Literal, LocalField, 
    OutputContextField, TernaryConditional, Variable
)
from graphql_compiler.compiler.compiler_frontend import IrAndMetadata, graphql_to_ir
from graphql_compiler.compiler.helpers import Location, get_only_element_from_collection
from graphql_compiler.interpreter.api import interpret_ir
from graphql_compiler.interpreter.debugging import InterpreterAdapterTap, TraceReplayAdapter
from graphql_compiler.interpreter.typedefs import DataContext, EdgeInfo, InterpreterAdapter
from graphql_compiler.schema import GraphQLDate, GraphQLDateTime, GraphQLDecimal
from graphql_compiler.tests.test_helpers import SCHEMA_TEXT

# %%
vertices = {
    'Animal': [
        {'name': 'Scooby Doo', 'uuid': '1001'},
        {'name': 'Hedwig', 'uuid': '1002'},
        {'name': 'Beethoven', 'uuid': '1003'},
        {'name': 'Pongo', 'uuid': '1004'},
        {'name': 'Perdy', 'uuid': '1005'},
        {'name': 'Dipstick', 'uuid': '1006'},
        {'name': 'Dottie', 'uuid': '1007'},
        {'name': 'Domino', 'uuid': '1008'},
        {'name': 'Little Dipper', 'uuid': '1009'},
        {'name': 'Oddball', 'uuid': '1010'},
    ],
}
edges = {
    'Animal_ParentOf': [
        ('1004', '1006'),
        ('1005', '1006'),
        ('1006', '1008'),
        ('1006', '1009'),
        ('1006', '1010'),
        ('1007', '1008'),
        ('1007', '1009'),
        ('1007', '1010'),
    ],
}

vertices_by_uuid = {
    vertex['uuid']: vertex
    for vertex in chain.from_iterable(vertices.values())
}


class InMemoryAdapter(InterpreterAdapter[dict]):
    def get_tokens_of_type(
        self,
        type_name: str, 
        **hints
    ) -> Iterable[dict]:
        return vertices[type_name]

    def project_property(
        self,
        data_contexts: Iterable[DataContext],
        current_type_name: str,
        field_name: str,
        **hints
    ) -> Iterable[Tuple[DataContext, Any]]:
        for data_context in data_contexts:
            current_token = data_context.current_token
            current_value = current_token[field_name] if current_token is not None else None
            yield (data_context, current_value)

    def project_neighbors(
        self,
        data_contexts: Iterable[DataContext], 
        current_type_name: str,
        edge_info: EdgeInfo,
        **hints
    ) -> Iterable[Tuple[DataContext, Iterable[dict]]]:
        direction, edge_name = edge_info
        edge_data = edges[edge_name]
        
        for data_context in data_contexts:
            neighbor_tokens = []
            current_token = data_context.current_token
            if current_token is not None:
                uuid = current_token['uuid']
                if direction == 'out':
                    neighbor_tokens = [
                        vertices_by_uuid[destination_uuid]
                        for source_uuid, destination_uuid in edge_data
                        if source_uuid == uuid
                    ]
                elif direction == 'in':
                    neighbor_tokens = [
                        vertices_by_uuid[source_uuid]
                        for source_uuid, destination_uuid in edge_data
                        if destination_uuid == uuid
                    ]
                else:
                    raise AssertionError()
                
            yield (data_context, neighbor_tokens)

    def can_coerce_to_type(
        self,
        data_contexts: Iterable[DataContext], 
        current_type_name: str,
        coerce_to_type_name: str,
        **hints
    ) -> Iterable[Tuple[DataContext, bool]]:
        # TODO(predrag): See if a redesign can make this be a no-op again.
        return zip(data_contexts, repeat(True))

# %%
schema = build_ast_schema(parse(SCHEMA_TEXT))

# %%
def recursion_sanity_check():
    depth_2 = """
{
    Animal {
        name @output(out_name: "start")
        
        out_Animal_ParentOf @recurse(depth: 2) {
            name @output(out_name: "first_recursion")
            
            in_Animal_ParentOf @recurse(depth: 2) {
                name @output(out_name: "second_recursion")
            }
        }
    }
}"""
    depth_3 = """
{
    Animal {
        name @output(out_name: "start")
        
        out_Animal_ParentOf @recurse(depth: 3) {
            name @output(out_name: "first_recursion")
            
            in_Animal_ParentOf @recurse(depth: 3) {
                name @output(out_name: "second_recursion")
            }
        }
    }
}"""
    depth_4 = """
{
    Animal {
        name @output(out_name: "start")
        
        out_Animal_ParentOf @recurse(depth: 4) {
            name @output(out_name: "first_recursion")
            
            in_Animal_ParentOf @recurse(depth: 4) {
                name @output(out_name: "second_recursion")
            }
        }
    }
}"""
    query_arguments = {}
    ir_and_metadata = graphql_to_ir(schema, depth_2)
    expected_result = list(interpret_ir(InMemoryAdapter(), ir_and_metadata, query_arguments))
    
    for query in (depth_3, depth_4):
        ir_and_metadata = graphql_to_ir(schema, query)
        actual_result = list(interpret_ir(InMemoryAdapter(), ir_and_metadata, query_arguments))
        
        if expected_result != actual_result:
            raise AssertionError(f"Result mimatch on query: {query}")
            
    print("Success!")
            
recursion_sanity_check()
# Out:
# Success!

# %%
query1 = '''
{
    Animal {
        name @output(out_name: "animal_name")
        uuid @output(out_name: "animal_uuid")
    }
}
'''
query_arguments1 = {}

# %%
query2 = '''
{
    Animal {
        name @output(out_name: "parent_name")

        out_Animal_ParentOf {
            name @output(out_name: "child_name")
        }
    }
}
'''
query_arguments2 = {}

# %%
query3 = '''{
    Animal {
        name @output(out_name: "parent_name")
        
        out_Animal_ParentOf @optional {
            name @filter(op_name: "in_collection", value: ["$child_names"])
                 @output(out_name: "child_name")
        }
    }
}'''
query_arguments3 = {
    "child_names": ['Domino', 'Dipstick', 'Oddball'],
}

# %%
query4 = '''{
    Animal {
        name @output(out_name: "ancestor_or_self_name")
        
        out_Animal_ParentOf @recurse(depth: 4) {
            name @filter(op_name: "in_collection", value: ["$names"])
                 @output(out_name: "descendant_or_self_name")
        }
    }
}'''
query_arguments4 = {
    "names": ['Domino', 'Dipstick', 'Oddball'],
}

# %%
query5 = '''{
    Animal {
        name @output(out_name: "ancestor_or_self_name")
        
        out_Animal_ParentOf @recurse(depth: 1) {
            name @filter(op_name: "in_collection", value: ["$names"])
                 @output(out_name: "descendant_or_self_name")
        }
    }
}'''
query_arguments5 = {
    "names": ['Domino', 'Dipstick', 'Oddball'],
}

# %%
query6 = '''
{
    Animal {
        name @output(out_name: "parent_name")

        out_Animal_ParentOf {
            name @filter(op_name: "in_collection", value: ["$child_names"])
                 @output(out_name: "child_name")
        }
    }
}
'''
query_arguments6 = {
    "child_names": ['Domino', 'Dipstick', 'Oddball'],
}

# %%
query7 = '''{
    Animal {
        name @output(out_name: "ancestor_or_self_name")
        
        out_Animal_ParentOf @recurse(depth: 4) {
            name @output(out_name: "descendant_or_self_name")
        }
    }
}'''
query_arguments7 = {}

# %%
query8 = '''{
    Animal {
        name @output(out_name: "start") @filter(op_name: "=", value: ["$start"])
        
        in_Animal_ParentOf @recurse(depth: 4) {
            name @output(out_name: "first_recursion")
        }
    }
}'''
query_arguments8ths  = {
    "start": "Dipstick"
}

# %%
query9 = '''{
    Animal {
        name @output(out_name: "start") @filter(op_name: "=", value: ["$start"])
        
        out_Animal_ParentOf @recurse(depth: 3) {
            name @output(out_name: "first_recursion")
            
            in_Animal_ParentOf @recurse(depth: 3) {
                name @output(out_name: "second_recursion")
            }
        }
    }
}'''
query_arguments9 = {
    "start": "Perdy"
}

# %%
query10 = '''{
    Animal {
        name @output(out_name: "start")
        
        out_Animal_ParentOf @recurse(depth: 3) {
            name @output(out_name: "first_recursion")
            
            in_Animal_ParentOf @recurse(depth: 3) {
                name @output(out_name: "second_recursion")
            }
        }
    }
}'''
query_arguments10 = {}

# %%
query11 = '''
{
    Animal {
        name @output(out_name: "grandparent_name")

        out_Animal_ParentOf {
            name @output(out_name: "parent_name")
            
            out_Animal_ParentOf {
                name @output(out_name: "child_name")
            }
        }
    }
}
'''
query_arguments11 = {}

# %%
query12 = '''
{
    Animal {
        name @output(out_name: "animal_name") @filter(op_name: "=", value: ["$name"])
        uuid @output(out_name: "animal_uuid")
        
        out_Animal_ParentOf {
            name @output(out_name: "child_name")
        }
        in_Animal_ParentOf {
            name @output(out_name: "parent_name")
        }
    }
}
'''
query_arguments12 = {
    "name": "Dipstick",
}

# %%
ir_and_metadata = graphql_to_ir(schema, query1)
args = query_arguments1
# pprint(ir_and_metadata.ir_blocks)

adapter = InterpreterAdapterTap(InMemoryAdapter())
result_gen = interpret_ir(adapter, ir_and_metadata, args)

# %%
next(result_gen)
# Out:
# {'animal_name': 'Scooby Doo', 'animal_uuid': '1001'}

# %%
trace = adapter.recorder.get_trace()
list(enumerate(trace.operations))
# Out:
# [(0,
#   AdapterOperation(kind='call', name='project_property', uid=0, parent_uid=-1, data=(('__input_iterable', 'Animal', 'uuid'), {}))),
#  (1,
#   AdapterOperation(kind='call', name='project_property', uid=1, parent_uid=-1, data=(('__input_iterable', 'Animal', 'name'), {}))),
#  (2,
#   AdapterOperation(kind='call', name='get_tokens_of_type', uid=2, parent_uid=-1, data=(('Animal',), {'runtime_arg_hints': {}, 'used_property_hints': frozenset({'name', 'uuid'}), 'filter_hints': [], 'neighbor_hints': []}))),
#  (3,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid=3, parent_uid=2, data={'name': 'Scooby Doo', 'uuid': '1001'})),
#  (4,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=4, parent_uid=1, data=DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (5,
#   AdapterOperation(kind='yield', name='project_property', uid=5, parent_uid=1, data=(DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Scooby Doo'))),
#  (6,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=6, parent_uid=0, data=DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value={'animal_name': 'Scooby Doo'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Scooby Doo'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (7,
#   AdapterOperation(kind='yield', name='project_property', uid=7, parent_uid=0, data=(DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value={'animal_name': 'Scooby Doo'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Scooby Doo'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), '1001')))]

# %%
list(result_gen)
trace = adapter.recorder.get_trace()

# %%
list(enumerate(trace.operations))
# Out:
# [(0,
#   AdapterOperation(kind='call', name='project_property', uid=0, parent_uid=-1, data=(('__input_iterable', 'Animal', 'uuid'), {}))),
#  (1,
#   AdapterOperation(kind='call', name='project_property', uid=1, parent_uid=-1, data=(('__input_iterable', 'Animal', 'name'), {}))),
#  (2,
#   AdapterOperation(kind='call', name='get_tokens_of_type', uid=2, parent_uid=-1, data=(('Animal',), {'runtime_arg_hints': {}, 'used_property_hints': frozenset({'name', 'uuid'}), 'filter_hints': [], 'neighbor_hints': []}))),
#  (3,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid=3, parent_uid=2, data={'name': 'Scooby Doo', 'uuid': '1001'})),
#  (4,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=4, parent_uid=1, data=DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (5,
#   AdapterOperation(kind='yield', name='project_property', uid=5, parent_uid=1, data=(DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Scooby Doo'))),
#  (6,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=6, parent_uid=0, data=DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value={'animal_name': 'Scooby Doo'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Scooby Doo'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (7,
#   AdapterOperation(kind='yield', name='project_property', uid=7, parent_uid=0, data=(DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value={'animal_name': 'Scooby Doo'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Scooby Doo'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), '1001'))),
#  (8,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid=8, parent_uid=2, data={'name': 'Hedwig', 'uuid': '1002'})),
#  (9,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=9, parent_uid=1, data=DataContext(current={'name': 'Hedwig', 'uuid': '1002'}, locations={Location(('Animal',), None, 1): {'name': 'Hedwig', 'uuid': '1002'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Hedwig', 'uuid': '1002'}, locations={Location(('Animal',), None, 1): {'name': 'Hedwig', 'uuid': '1002'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (10,
#   AdapterOperation(kind='yield', name='project_property', uid=10, parent_uid=1, data=(DataContext(current={'name': 'Hedwig', 'uuid': '1002'}, locations={Location(('Animal',), None, 1): {'name': 'Hedwig', 'uuid': '1002'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Hedwig', 'uuid': '1002'}, locations={Location(('Animal',), None, 1): {'name': 'Hedwig', 'uuid': '1002'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Hedwig'))),
#  (11,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=11, parent_uid=0, data=DataContext(current={'name': 'Hedwig', 'uuid': '1002'}, locations={Location(('Animal',), None, 1): {'name': 'Hedwig', 'uuid': '1002'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Hedwig', 'uuid': '1002'}, locations={Location(('Animal',), None, 1): {'name': 'Hedwig', 'uuid': '1002'}}, stack=ImmutableStack(value={'animal_name': 'Hedwig'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Hedwig'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (12,
#   AdapterOperation(kind='yield', name='project_property', uid=12, parent_uid=0, data=(DataContext(current={'name': 'Hedwig', 'uuid': '1002'}, locations={Location(('Animal',), None, 1): {'name': 'Hedwig', 'uuid': '1002'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Hedwig', 'uuid': '1002'}, locations={Location(('Animal',), None, 1): {'name': 'Hedwig', 'uuid': '1002'}}, stack=ImmutableStack(value={'animal_name': 'Hedwig'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Hedwig'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), '1002'))),
#  (13,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid=13, parent_uid=2, data={'name': 'Beethoven', 'uuid': '1003'})),
#  (14,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=14, parent_uid=1, data=DataContext(current={'name': 'Beethoven', 'uuid': '1003'}, locations={Location(('Animal',), None, 1): {'name': 'Beethoven', 'uuid': '1003'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Beethoven', 'uuid': '1003'}, locations={Location(('Animal',), None, 1): {'name': 'Beethoven', 'uuid': '1003'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (15,
#   AdapterOperation(kind='yield', name='project_property', uid=15, parent_uid=1, data=(DataContext(current={'name': 'Beethoven', 'uuid': '1003'}, locations={Location(('Animal',), None, 1): {'name': 'Beethoven', 'uuid': '1003'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Beethoven', 'uuid': '1003'}, locations={Location(('Animal',), None, 1): {'name': 'Beethoven', 'uuid': '1003'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Beethoven'))),
#  (16,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=16, parent_uid=0, data=DataContext(current={'name': 'Beethoven', 'uuid': '1003'}, locations={Location(('Animal',), None, 1): {'name': 'Beethoven', 'uuid': '1003'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Beethoven', 'uuid': '1003'}, locations={Location(('Animal',), None, 1): {'name': 'Beethoven', 'uuid': '1003'}}, stack=ImmutableStack(value={'animal_name': 'Beethoven'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Beethoven'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (17,
#   AdapterOperation(kind='yield', name='project_property', uid=17, parent_uid=0, data=(DataContext(current={'name': 'Beethoven', 'uuid': '1003'}, locations={Location(('Animal',), None, 1): {'name': 'Beethoven', 'uuid': '1003'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Beethoven', 'uuid': '1003'}, locations={Location(('Animal',), None, 1): {'name': 'Beethoven', 'uuid': '1003'}}, stack=ImmutableStack(value={'animal_name': 'Beethoven'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Beethoven'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), '1003'))),
#  (18,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid=18, parent_uid=2, data={'name': 'Pongo', 'uuid': '1004'})),
#  (19,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=19, parent_uid=1, data=DataContext(current={'name': 'Pongo', 'uuid': '1004'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Pongo', 'uuid': '1004'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (20,
#   AdapterOperation(kind='yield', name='project_property', uid=20, parent_uid=1, data=(DataContext(current={'name': 'Pongo', 'uuid': '1004'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Pongo', 'uuid': '1004'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Pongo'))),
#  (21,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=21, parent_uid=0, data=DataContext(current={'name': 'Pongo', 'uuid': '1004'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Pongo', 'uuid': '1004'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'}}, stack=ImmutableStack(value={'animal_name': 'Pongo'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Pongo'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (22,
#   AdapterOperation(kind='yield', name='project_property', uid=22, parent_uid=0, data=(DataContext(current={'name': 'Pongo', 'uuid': '1004'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Pongo', 'uuid': '1004'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'}}, stack=ImmutableStack(value={'animal_name': 'Pongo'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Pongo'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), '1004'))),
#  (23,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid=23, parent_uid=2, data={'name': 'Perdy', 'uuid': '1005'})),
#  (24,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=24, parent_uid=1, data=DataContext(current={'name': 'Perdy', 'uuid': '1005'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Perdy', 'uuid': '1005'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (25,
#   AdapterOperation(kind='yield', name='project_property', uid=25, parent_uid=1, data=(DataContext(current={'name': 'Perdy', 'uuid': '1005'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Perdy', 'uuid': '1005'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Perdy'))),
#  (26,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=26, parent_uid=0, data=DataContext(current={'name': 'Perdy', 'uuid': '1005'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Perdy', 'uuid': '1005'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'}}, stack=ImmutableStack(value={'animal_name': 'Perdy'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Perdy'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (27,
#   AdapterOperation(kind='yield', name='project_property', uid=27, parent_uid=0, data=(DataContext(current={'name': 'Perdy', 'uuid': '1005'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Perdy', 'uuid': '1005'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'}}, stack=ImmutableStack(value={'animal_name': 'Perdy'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Perdy'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), '1005'))),
#  (28,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid=28, parent_uid=2, data={'name': 'Dipstick', 'uuid': '1006'})),
#  (29,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=29, parent_uid=1, data=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (30,
#   AdapterOperation(kind='yield', name='project_property', uid=30, parent_uid=1, data=(DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Dipstick'))),
#  (31,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=31, parent_uid=0, data=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'}}, stack=ImmutableStack(value={'animal_name': 'Dipstick'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Dipstick'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (32,
#   AdapterOperation(kind='yield', name='project_property', uid=32, parent_uid=0, data=(DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'}}, stack=ImmutableStack(value={'animal_name': 'Dipstick'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Dipstick'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), '1006'))),
#  (33,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid=33, parent_uid=2, data={'name': 'Dottie', 'uuid': '1007'})),
#  (34,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=34, parent_uid=1, data=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (35,
#   AdapterOperation(kind='yield', name='project_property', uid=35, parent_uid=1, data=(DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Dottie'))),
#  (36,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=36, parent_uid=0, data=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'}}, stack=ImmutableStack(value={'animal_name': 'Dottie'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Dottie'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (37,
#   AdapterOperation(kind='yield', name='project_property', uid=37, parent_uid=0, data=(DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'}}, stack=ImmutableStack(value={'animal_name': 'Dottie'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Dottie'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), '1007'))),
#  (38,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid=38, parent_uid=2, data={'name': 'Domino', 'uuid': '1008'})),
#  (39,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=39, parent_uid=1, data=DataContext(current={'name': 'Domino', 'uuid': '1008'}, locations={Location(('Animal',), None, 1): {'name': 'Domino', 'uuid': '1008'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Domino', 'uuid': '1008'}, locations={Location(('Animal',), None, 1): {'name': 'Domino', 'uuid': '1008'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (40,
#   AdapterOperation(kind='yield', name='project_property', uid=40, parent_uid=1, data=(DataContext(current={'name': 'Domino', 'uuid': '1008'}, locations={Location(('Animal',), None, 1): {'name': 'Domino', 'uuid': '1008'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Domino', 'uuid': '1008'}, locations={Location(('Animal',), None, 1): {'name': 'Domino', 'uuid': '1008'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Domino'))),
#  (41,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=41, parent_uid=0, data=DataContext(current={'name': 'Domino', 'uuid': '1008'}, locations={Location(('Animal',), None, 1): {'name': 'Domino', 'uuid': '1008'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Domino', 'uuid': '1008'}, locations={Location(('Animal',), None, 1): {'name': 'Domino', 'uuid': '1008'}}, stack=ImmutableStack(value={'animal_name': 'Domino'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Domino'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (42,
#   AdapterOperation(kind='yield', name='project_property', uid=42, parent_uid=0, data=(DataContext(current={'name': 'Domino', 'uuid': '1008'}, locations={Location(('Animal',), None, 1): {'name': 'Domino', 'uuid': '1008'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Domino', 'uuid': '1008'}, locations={Location(('Animal',), None, 1): {'name': 'Domino', 'uuid': '1008'}}, stack=ImmutableStack(value={'animal_name': 'Domino'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Domino'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), '1008'))),
#  (43,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid=43, parent_uid=2, data={'name': 'Little Dipper', 'uuid': '1009'})),
#  (44,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=44, parent_uid=1, data=DataContext(current={'name': 'Little Dipper', 'uuid': '1009'}, locations={Location(('Animal',), None, 1): {'name': 'Little Dipper', 'uuid': '1009'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Little Dipper', 'uuid': '1009'}, locations={Location(('Animal',), None, 1): {'name': 'Little Dipper', 'uuid': '1009'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (45,
#   AdapterOperation(kind='yield', name='project_property', uid=45, parent_uid=1, data=(DataContext(current={'name': 'Little Dipper', 'uuid': '1009'}, locations={Location(('Animal',), None, 1): {'name': 'Little Dipper', 'uuid': '1009'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Little Dipper', 'uuid': '1009'}, locations={Location(('Animal',), None, 1): {'name': 'Little Dipper', 'uuid': '1009'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Little Dipper'))),
#  (46,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=46, parent_uid=0, data=DataContext(current={'name': 'Little Dipper', 'uuid': '1009'}, locations={Location(('Animal',), None, 1): {'name': 'Little Dipper', 'uuid': '1009'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Little Dipper', 'uuid': '1009'}, locations={Location(('Animal',), None, 1): {'name': 'Little Dipper', 'uuid': '1009'}}, stack=ImmutableStack(value={'animal_name': 'Little Dipper'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Little Dipper'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (47,
#   AdapterOperation(kind='yield', name='project_property', uid=47, parent_uid=0, data=(DataContext(current={'name': 'Little Dipper', 'uuid': '1009'}, locations={Location(('Animal',), None, 1): {'name': 'Little Dipper', 'uuid': '1009'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Little Dipper', 'uuid': '1009'}, locations={Location(('Animal',), None, 1): {'name': 'Little Dipper', 'uuid': '1009'}}, stack=ImmutableStack(value={'animal_name': 'Little Dipper'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Little Dipper'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), '1009'))),
#  (48,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid=48, parent_uid=2, data={'name': 'Oddball', 'uuid': '1010'})),
#  (49,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=49, parent_uid=1, data=DataContext(current={'name': 'Oddball', 'uuid': '1010'}, locations={Location(('Animal',), None, 1): {'name': 'Oddball', 'uuid': '1010'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Oddball', 'uuid': '1010'}, locations={Location(('Animal',), None, 1): {'name': 'Oddball', 'uuid': '1010'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (50,
#   AdapterOperation(kind='yield', name='project_property', uid=50, parent_uid=1, data=(DataContext(current={'name': 'Oddball', 'uuid': '1010'}, locations={Location(('Animal',), None, 1): {'name': 'Oddball', 'uuid': '1010'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Oddball', 'uuid': '1010'}, locations={Location(('Animal',), None, 1): {'name': 'Oddball', 'uuid': '1010'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Oddball'))),
#  (51,
#   AdapterOperation(kind='yield', name='__input_iterable', uid=51, parent_uid=0, data=DataContext(current={'name': 'Oddball', 'uuid': '1010'}, locations={Location(('Animal',), None, 1): {'name': 'Oddball', 'uuid': '1010'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Oddball', 'uuid': '1010'}, locations={Location(('Animal',), None, 1): {'name': 'Oddball', 'uuid': '1010'}}, stack=ImmutableStack(value={'animal_name': 'Oddball'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Oddball'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (52,
#   AdapterOperation(kind='yield', name='project_property', uid=52, parent_uid=0, data=(DataContext(current={'name': 'Oddball', 'uuid': '1010'}, locations={Location(('Animal',), None, 1): {'name': 'Oddball', 'uuid': '1010'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Oddball', 'uuid': '1010'}, locations={Location(('Animal',), None, 1): {'name': 'Oddball', 'uuid': '1010'}}, stack=ImmutableStack(value={'animal_name': 'Oddball'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'animal_name': 'Oddball'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), '1010')))]

# %%
replay_adapter = TraceReplayAdapter(trace)

# %%
result_gen = interpret_ir(replay_adapter, ir_and_metadata, args)

# %%
list(result_gen)
# Out:
# [{'animal_name': 'Scooby Doo', 'animal_uuid': '1001'},
#  {'animal_name': 'Hedwig', 'animal_uuid': '1002'},
#  {'animal_name': 'Beethoven', 'animal_uuid': '1003'},
#  {'animal_name': 'Pongo', 'animal_uuid': '1004'},
#  {'animal_name': 'Perdy', 'animal_uuid': '1005'},
#  {'animal_name': 'Dipstick', 'animal_uuid': '1006'},
#  {'animal_name': 'Dottie', 'animal_uuid': '1007'},
#  {'animal_name': 'Domino', 'animal_uuid': '1008'},
#  {'animal_name': 'Little Dipper', 'animal_uuid': '1009'},
#  {'animal_name': 'Oddball', 'animal_uuid': '1010'}]
