# %%
from abc import ABCMeta, abstractmethod
from collections import namedtuple
from itertools import chain, repeat
from pprint import pformat, pprint
from typing import (
    AbstractSet, Any, Callable, Collection, Dict, Generator, Generic, Iterable, List, Mapping,
    NamedTuple, Optional, Tuple, TypeVar, Union
)

from graphql import GraphQLList, GraphQLString, parse
from graphql.utilities.build_ast_schema import build_ast_schema
from graphql_compiler.compiler.blocks import (
    Backtrack, CoerceType, ConstructResult, EndOptional, Filter, GlobalOperationsStart, 
    MarkLocation, Recurse, QueryRoot, Traverse
)
from graphql_compiler.compiler.compiler_entities import BasicBlock, Expression
from graphql_compiler.compiler.expressions import (
    BinaryComposition, ContextField, ContextFieldExistence, Literal, LocalField, 
    OutputContextField, TernaryConditional, Variable
)
from graphql_compiler.compiler.compiler_frontend import IrAndMetadata, graphql_to_ir
from graphql_compiler.compiler.helpers import Location, get_only_element_from_collection
from graphql_compiler.interpreter.api import interpret_ir
from graphql_compiler.interpreter.debugging import InterpreterAdapterTap, TraceReplayAdapter
from graphql_compiler.interpreter.typedefs import DataContext, EdgeInfo, InterpreterAdapter
from graphql_compiler.schema import GraphQLDate, GraphQLDateTime, GraphQLDecimal
from graphql_compiler.tests.test_helpers import SCHEMA_TEXT

# %%
vertices = {
    'Animal': [
        {'name': 'Scooby Doo', 'uuid': '1001'},
        {'name': 'Hedwig', 'uuid': '1002'},
        {'name': 'Beethoven', 'uuid': '1003'},
        {'name': 'Pongo', 'uuid': '1004'},
        {'name': 'Perdy', 'uuid': '1005'},
        {'name': 'Dipstick', 'uuid': '1006'},
        {'name': 'Dottie', 'uuid': '1007'},
        {'name': 'Domino', 'uuid': '1008'},
        {'name': 'Little Dipper', 'uuid': '1009'},
        {'name': 'Oddball', 'uuid': '1010'},
    ],
}
edges = {
    'Animal_ParentOf': [
        ('1004', '1006'),
        ('1005', '1006'),
        ('1006', '1008'),
        ('1006', '1009'),
        ('1006', '1010'),
        ('1007', '1008'),
        ('1007', '1009'),
        ('1007', '1010'),
    ],
}

vertices_by_uuid = {
    vertex['uuid']: vertex
    for vertex in chain.from_iterable(vertices.values())
}


class InMemoryAdapter(InterpreterAdapter[dict]):
    def get_tokens_of_type(
        self,
        type_name: str, 
        **hints
    ) -> Iterable[dict]:
        return vertices[type_name]

    def project_property(
        self,
        data_contexts: Iterable[DataContext],
        current_type_name: str,
        field_name: str,
        **hints
    ) -> Iterable[Tuple[DataContext, Any]]:
        for data_context in data_contexts:
            current_token = data_context.current_token
            current_value = current_token[field_name] if current_token is not None else None
            yield (data_context, current_value)

    def project_neighbors(
        self,
        data_contexts: Iterable[DataContext], 
        current_type_name: str,
        edge_info: EdgeInfo,
        **hints
    ) -> Iterable[Tuple[DataContext, Iterable[dict]]]:
        direction, edge_name = edge_info
        edge_data = edges[edge_name]
        
        for data_context in data_contexts:
            neighbor_tokens = []
            current_token = data_context.current_token
            if current_token is not None:
                uuid = current_token['uuid']
                if direction == 'out':
                    neighbor_tokens = [
                        vertices_by_uuid[destination_uuid]
                        for source_uuid, destination_uuid in edge_data
                        if source_uuid == uuid
                    ]
                elif direction == 'in':
                    neighbor_tokens = [
                        vertices_by_uuid[source_uuid]
                        for source_uuid, destination_uuid in edge_data
                        if destination_uuid == uuid
                    ]
                else:
                    raise AssertionError()
                
            yield (data_context, neighbor_tokens)

    def can_coerce_to_type(
        self,
        data_contexts: Iterable[DataContext], 
        current_type_name: str,
        coerce_to_type_name: str,
        **hints
    ) -> Iterable[Tuple[DataContext, bool]]:
        # TODO(predrag): See if a redesign can make this be a no-op again.
        return zip(data_contexts, repeat(True))

# %%
schema = build_ast_schema(parse(SCHEMA_TEXT))

# %%
def recursion_sanity_check():
    depth_2 = """
{
    Animal {
        name @output(out_name: "start")
        
        out_Animal_ParentOf @recurse(depth: 2) {
            name @output(out_name: "first_recursion")
            
            in_Animal_ParentOf @recurse(depth: 2) {
                name @output(out_name: "second_recursion")
            }
        }
    }
}"""
    depth_3 = """
{
    Animal {
        name @output(out_name: "start")
        
        out_Animal_ParentOf @recurse(depth: 3) {
            name @output(out_name: "first_recursion")
            
            in_Animal_ParentOf @recurse(depth: 3) {
                name @output(out_name: "second_recursion")
            }
        }
    }
}"""
    depth_4 = """
{
    Animal {
        name @output(out_name: "start")
        
        out_Animal_ParentOf @recurse(depth: 4) {
            name @output(out_name: "first_recursion")
            
            in_Animal_ParentOf @recurse(depth: 4) {
                name @output(out_name: "second_recursion")
            }
        }
    }
}"""
    query_arguments = {}
    ir_and_metadata = graphql_to_ir(schema, depth_2)
    expected_result = list(interpret_ir(InMemoryAdapter(), ir_and_metadata, query_arguments))
    
    for query in (depth_3, depth_4):
        ir_and_metadata = graphql_to_ir(schema, query)
        actual_result = list(interpret_ir(InMemoryAdapter(), ir_and_metadata, query_arguments))
        
        if expected_result != actual_result:
            raise AssertionError(f"Result mimatch on query: {query}")
            
    print("Success!")
            
recursion_sanity_check()
# Out:
# Success!

# %%
query1 = '''
{
    Animal {
        name @output(out_name: "animal_name")
        uuid @output(out_name: "animal_uuid")
    }
}
'''
query_arguments1 = {}

# %%
query2 = '''
{
    Animal {
        name @output(out_name: "parent_name")

        out_Animal_ParentOf {
            name @output(out_name: "child_name")
        }
    }
}
'''
query_arguments2 = {}

# %%
query3 = '''{
    Animal {
        name @output(out_name: "parent_name")
        
        out_Animal_ParentOf @optional {
            name @filter(op_name: "in_collection", value: ["$child_names"])
                 @output(out_name: "child_name")
        }
    }
}'''
query_arguments3 = {
    "child_names": ['Domino', 'Dipstick', 'Oddball'],
}

# %%
query4 = '''{
    Animal {
        name @output(out_name: "ancestor_or_self_name")
        
        out_Animal_ParentOf @recurse(depth: 4) {
            name @filter(op_name: "in_collection", value: ["$names"])
                 @output(out_name: "descendant_or_self_name")
        }
    }
}'''
query_arguments4 = {
    "names": ['Domino', 'Dipstick', 'Oddball'],
}

# %%
query5 = '''{
    Animal {
        name @output(out_name: "ancestor_or_self_name")
        
        out_Animal_ParentOf @recurse(depth: 1) {
            name @filter(op_name: "in_collection", value: ["$names"])
                 @output(out_name: "descendant_or_self_name")
        }
    }
}'''
query_arguments5 = {
    "names": ['Domino', 'Dipstick', 'Oddball'],
}

# %%
query6 = '''
{
    Animal {
        name @output(out_name: "parent_name")

        out_Animal_ParentOf {
            name @filter(op_name: "in_collection", value: ["$child_names"])
                 @output(out_name: "child_name")
        }
    }
}
'''
query_arguments6 = {
    "child_names": ['Domino', 'Dipstick', 'Oddball'],
}

# %%
query7 = '''{
    Animal {
        name @output(out_name: "ancestor_or_self_name")
        
        out_Animal_ParentOf @recurse(depth: 4) {
            name @output(out_name: "descendant_or_self_name")
        }
    }
}'''
query_arguments7 = {}

# %%
query8 = '''{
    Animal {
        name @output(out_name: "start") @filter(op_name: "=", value: ["$start"])
        
        in_Animal_ParentOf @recurse(depth: 4) {
            name @output(out_name: "first_recursion")
        }
    }
}'''
query_arguments8ths  = {
    "start": "Dipstick"
}

# %%
query9 = '''{
    Animal {
        name @output(out_name: "start") @filter(op_name: "=", value: ["$start"])
        
        out_Animal_ParentOf @recurse(depth: 3) {
            name @output(out_name: "first_recursion")
            
            in_Animal_ParentOf @recurse(depth: 3) {
                name @output(out_name: "second_recursion")
            }
        }
    }
}'''
query_arguments9 = {
    "start": "Perdy"
}

# %%
query10 = '''{
    Animal {
        name @output(out_name: "start")
        
        out_Animal_ParentOf @recurse(depth: 3) {
            name @output(out_name: "first_recursion")
            
            in_Animal_ParentOf @recurse(depth: 3) {
                name @output(out_name: "second_recursion")
            }
        }
    }
}'''
query_arguments10 = {}

# %%
query11 = '''
{
    Animal {
        name @output(out_name: "grandparent_name")

        out_Animal_ParentOf {
            name @output(out_name: "parent_name")
            
            out_Animal_ParentOf {
                name @output(out_name: "child_name")
            }
        }
    }
}
'''
query_arguments11 = {}

# %%
query12 = '''
{
    Animal {
        name @output(out_name: "animal_name") @filter(op_name: "=", value: ["$name"])
        uuid @output(out_name: "animal_uuid")
        
        out_Animal_ParentOf {
            name @output(out_name: "child_name")
        }
        in_Animal_ParentOf {
            name @output(out_name: "parent_name")
        }
    }
}
'''
query_arguments12 = {
    "name": "Dipstick",
}

# %%
ir_and_metadata = graphql_to_ir(schema, query2)
args = query_arguments2
# pprint(ir_and_metadata.ir_blocks)

adapter = InterpreterAdapterTap(InMemoryAdapter())
result_gen = interpret_ir(adapter, ir_and_metadata, args)

# %%
next(result_gen)
# Out:
# {'parent_name': 'Pongo', 'child_name': 'Dipstick'}

# %%
list(result_gen)
trace = adapter.recorder.get_trace()

# %%
list(enumerate(trace.operations))
# Out:
# [(0,
#   AdapterOperation(kind='call', name='project_property', uid='92457df4-8a82-4d06-a40b-f58effe075a4', parent_uid='c47008f5-6d66-4323-8dd8-fdcc65737ba8', data=(('__input_iterable', 'Animal', 'name'), {}))),
#  (1,
#   AdapterOperation(kind='call', name='project_property', uid='42f1189d-8877-420a-99f3-4b40f17255a2', parent_uid='c47008f5-6d66-4323-8dd8-fdcc65737ba8', data=(('__input_iterable', 'Animal', 'name'), {}))),
#  (2,
#   AdapterOperation(kind='call', name='project_neighbors', uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', parent_uid='c47008f5-6d66-4323-8dd8-fdcc65737ba8', data=(('__input_iterable', 'Animal', ('out', 'Animal_ParentOf')), {'runtime_arg_hints': {}, 'used_property_hints': frozenset({'name'}), 'filter_hints': [], 'neighbor_hints': []}))),
#  (3,
#   AdapterOperation(kind='call', name='get_tokens_of_type', uid='a9a0f488-c926-4e07-afd1-a8b786285fc6', parent_uid='c47008f5-6d66-4323-8dd8-fdcc65737ba8', data=(('Animal',), {'runtime_arg_hints': {}, 'used_property_hints': frozenset({'name'}), 'filter_hints': [], 'neighbor_hints': [(('out', 'Animal_ParentOf'), None)]}))),
#  (4,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid='4cb0b053-b749-4282-8259-0ea8e5131ac1', parent_uid='a9a0f488-c926-4e07-afd1-a8b786285fc6', data={'name': 'Scooby Doo', 'uuid': '1001'})),
#  (5,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='7f565d45-2127-40cc-805d-fbf3b2bd64d5', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None))),
#  (6,
#   AdapterOperation(kind='yield', name='project_neighbors', uid='77d25186-5d91-43ac-a203-f1cafd527f13', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=(DataContext(current={'name': 'Scooby Doo', 'uuid': '1001'}, locations={Location(('Animal',), None, 1): {'name': 'Scooby Doo', 'uuid': '1001'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None), '__output_iterable_0'))),
#  (7,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid='7b9fd840-49a1-473b-9d6f-f4428cf85ca7', parent_uid='a9a0f488-c926-4e07-afd1-a8b786285fc6', data={'name': 'Hedwig', 'uuid': '1002'})),
#  (8,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='9315f8a7-f49d-4bb1-b469-ec6caeb05050', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=DataContext(current={'name': 'Hedwig', 'uuid': '1002'}, locations={Location(('Animal',), None, 1): {'name': 'Hedwig', 'uuid': '1002'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None))),
#  (9,
#   AdapterOperation(kind='yield', name='project_neighbors', uid='c76fe4aa-3873-4829-8a30-1047e9ee4556', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=(DataContext(current={'name': 'Hedwig', 'uuid': '1002'}, locations={Location(('Animal',), None, 1): {'name': 'Hedwig', 'uuid': '1002'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None), '__output_iterable_1'))),
#  (10,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid='bef00aff-e43c-4e14-85fb-76fa6644fe54', parent_uid='a9a0f488-c926-4e07-afd1-a8b786285fc6', data={'name': 'Beethoven', 'uuid': '1003'})),
#  (11,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='5ffbf505-70bc-46d3-9555-6ca34c0f5c87', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=DataContext(current={'name': 'Beethoven', 'uuid': '1003'}, locations={Location(('Animal',), None, 1): {'name': 'Beethoven', 'uuid': '1003'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None))),
#  (12,
#   AdapterOperation(kind='yield', name='project_neighbors', uid='3bd0334b-5f99-49c5-961c-119956d6d97e', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=(DataContext(current={'name': 'Beethoven', 'uuid': '1003'}, locations={Location(('Animal',), None, 1): {'name': 'Beethoven', 'uuid': '1003'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None), '__output_iterable_2'))),
#  (13,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid='144c5fd8-ff1d-4f49-98de-5c9a02e97701', parent_uid='a9a0f488-c926-4e07-afd1-a8b786285fc6', data={'name': 'Pongo', 'uuid': '1004'})),
#  (14,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='392cc1c3-dd1d-481b-94fb-90ceb9a12c00', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=DataContext(current={'name': 'Pongo', 'uuid': '1004'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None))),
#  (15,
#   AdapterOperation(kind='yield', name='project_neighbors', uid='07bc9489-16ec-4636-8f11-280f0fc00147', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=(DataContext(current={'name': 'Pongo', 'uuid': '1004'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None), '__output_iterable_3'))),
#  (16,
#   AdapterOperation(kind='yield', name='__output_iterable_3', uid='46ff5943-9203-4144-b21e-f6a5cc74a307', parent_uid='07bc9489-16ec-4636-8f11-280f0fc00147', data={'name': 'Dipstick', 'uuid': '1006'})),
#  (17,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='f6cdb5d5-1560-45f2-b8c0-84ec0e7ef7d0', parent_uid='42f1189d-8877-420a-99f3-4b40f17255a2', data=DataContext(current={'name': 'Pongo', 'uuid': '1004'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Dipstick',
#                                                           'uuid': '1006'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Pongo', 'uuid': '1004'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Dipstick',
#                                                           'uuid': '1006'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (18,
#   AdapterOperation(kind='yield', name='project_property', uid='1e2e3d06-1c60-4e3f-ba30-ac678a36b150', parent_uid='42f1189d-8877-420a-99f3-4b40f17255a2', data=(DataContext(current={'name': 'Pongo', 'uuid': '1004'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Dipstick',
#                                                           'uuid': '1006'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Pongo', 'uuid': '1004'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Dipstick',
#                                                           'uuid': '1006'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Pongo'))),
#  (19,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='cf9b41b2-227d-40ff-9be6-0e53cc837a83', parent_uid='92457df4-8a82-4d06-a40b-f58effe075a4', data=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Dipstick',
#                                                           'uuid': '1006'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Pongo', 'uuid': '1004'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Dipstick',
#                                                           'uuid': '1006'}}, stack=ImmutableStack(value={'parent_name': 'Pongo'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'parent_name': 'Pongo'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (20,
#   AdapterOperation(kind='yield', name='project_property', uid='d09dbe66-81c5-472f-99c0-0d19c30f48d9', parent_uid='92457df4-8a82-4d06-a40b-f58effe075a4', data=(DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Dipstick',
#                                                           'uuid': '1006'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Pongo', 'uuid': '1004'}, locations={Location(('Animal',), None, 1): {'name': 'Pongo', 'uuid': '1004'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Dipstick',
#                                                           'uuid': '1006'}}, stack=ImmutableStack(value={'parent_name': 'Pongo'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'parent_name': 'Pongo'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Dipstick'))),
#  (21,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid='0e475f58-98d7-41ca-bbcc-60daab896218', parent_uid='a9a0f488-c926-4e07-afd1-a8b786285fc6', data={'name': 'Perdy', 'uuid': '1005'})),
#  (22,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='85c1c94c-6261-4ae5-8059-e28fd5c59839', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=DataContext(current={'name': 'Perdy', 'uuid': '1005'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None))),
#  (23,
#   AdapterOperation(kind='yield', name='project_neighbors', uid='69f1029c-0487-4d0e-b8c1-b881424b4340', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=(DataContext(current={'name': 'Perdy', 'uuid': '1005'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None), '__output_iterable_4'))),
#  (24,
#   AdapterOperation(kind='yield', name='__output_iterable_4', uid='8fc30e88-e855-4d73-92d9-f8b2882b2ba7', parent_uid='69f1029c-0487-4d0e-b8c1-b881424b4340', data={'name': 'Dipstick', 'uuid': '1006'})),
#  (25,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='3e8218c4-595b-4a58-9646-cde819ed82f1', parent_uid='42f1189d-8877-420a-99f3-4b40f17255a2', data=DataContext(current={'name': 'Perdy', 'uuid': '1005'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Dipstick',
#                                                           'uuid': '1006'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Perdy', 'uuid': '1005'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Dipstick',
#                                                           'uuid': '1006'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (26,
#   AdapterOperation(kind='yield', name='project_property', uid='d92e2e2f-8bd8-477e-9831-c7a684439182', parent_uid='42f1189d-8877-420a-99f3-4b40f17255a2', data=(DataContext(current={'name': 'Perdy', 'uuid': '1005'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Dipstick',
#                                                           'uuid': '1006'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Perdy', 'uuid': '1005'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Dipstick',
#                                                           'uuid': '1006'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Perdy'))),
#  (27,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='f8045f9c-b3c3-4309-a425-a3e64a0c5cb3', parent_uid='92457df4-8a82-4d06-a40b-f58effe075a4', data=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Dipstick',
#                                                           'uuid': '1006'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Perdy', 'uuid': '1005'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Dipstick',
#                                                           'uuid': '1006'}}, stack=ImmutableStack(value={'parent_name': 'Perdy'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'parent_name': 'Perdy'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (28,
#   AdapterOperation(kind='yield', name='project_property', uid='8618b3d3-0297-47fc-8965-1c1a908d6c05', parent_uid='92457df4-8a82-4d06-a40b-f58effe075a4', data=(DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Dipstick',
#                                                           'uuid': '1006'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Perdy', 'uuid': '1005'}, locations={Location(('Animal',), None, 1): {'name': 'Perdy', 'uuid': '1005'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Dipstick',
#                                                           'uuid': '1006'}}, stack=ImmutableStack(value={'parent_name': 'Perdy'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'parent_name': 'Perdy'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Dipstick'))),
#  (29,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid='095c3094-90c8-4d20-8e1c-945784553a47', parent_uid='a9a0f488-c926-4e07-afd1-a8b786285fc6', data={'name': 'Dipstick', 'uuid': '1006'})),
#  (30,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='c0bfba03-acc8-4770-984b-f0fffbd35bf4', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None))),
#  (31,
#   AdapterOperation(kind='yield', name='project_neighbors', uid='1e735b33-c479-4c00-8c64-50da57c0996b', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=(DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None), '__output_iterable_5'))),
#  (32,
#   AdapterOperation(kind='yield', name='__output_iterable_5', uid='ac8b16af-5f53-4fdf-818b-433f0a515958', parent_uid='1e735b33-c479-4c00-8c64-50da57c0996b', data={'name': 'Domino', 'uuid': '1008'})),
#  (33,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='e30bcfb9-6102-4d14-979e-7c1e1b939e21', parent_uid='42f1189d-8877-420a-99f3-4b40f17255a2', data=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Domino',
#                                                           'uuid': '1008'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Domino',
#                                                           'uuid': '1008'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (34,
#   AdapterOperation(kind='yield', name='project_property', uid='e4265f14-7e62-4771-b7a7-58ce82bf0b7b', parent_uid='42f1189d-8877-420a-99f3-4b40f17255a2', data=(DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Domino',
#                                                           'uuid': '1008'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Domino',
#                                                           'uuid': '1008'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Dipstick'))),
#  (35,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='39d3d96a-fd70-450f-a37e-2aa0f4264e4f', parent_uid='92457df4-8a82-4d06-a40b-f58effe075a4', data=DataContext(current={'name': 'Domino', 'uuid': '1008'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Domino',
#                                                           'uuid': '1008'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Domino',
#                                                           'uuid': '1008'}}, stack=ImmutableStack(value={'parent_name': 'Dipstick'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'parent_name': 'Dipstick'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (36,
#   AdapterOperation(kind='yield', name='project_property', uid='16593cf7-ba25-4cae-8f24-0c684168dfb0', parent_uid='92457df4-8a82-4d06-a40b-f58effe075a4', data=(DataContext(current={'name': 'Domino', 'uuid': '1008'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Domino',
#                                                           'uuid': '1008'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Domino',
#                                                           'uuid': '1008'}}, stack=ImmutableStack(value={'parent_name': 'Dipstick'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'parent_name': 'Dipstick'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Domino'))),
#  (37,
#   AdapterOperation(kind='yield', name='__output_iterable_5', uid='3b977351-b205-46a9-a285-2483adda269c', parent_uid='1e735b33-c479-4c00-8c64-50da57c0996b', data={'name': 'Little Dipper', 'uuid': '1009'})),
#  (38,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='5c29b07d-ab8f-48cb-b18e-1d1ed0c5810c', parent_uid='42f1189d-8877-420a-99f3-4b40f17255a2', data=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Little Dipper',
#                                                           'uuid': '1009'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Little Dipper',
#                                                           'uuid': '1009'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (39,
#   AdapterOperation(kind='yield', name='project_property', uid='a766a0dd-0c9c-4465-b094-f6a8d92de360', parent_uid='42f1189d-8877-420a-99f3-4b40f17255a2', data=(DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Little Dipper',
#                                                           'uuid': '1009'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Little Dipper',
#                                                           'uuid': '1009'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Dipstick'))),
#  (40,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='c6ccf38d-5a43-4f60-be9c-eb120ddecdd8', parent_uid='92457df4-8a82-4d06-a40b-f58effe075a4', data=DataContext(current={'name': 'Little Dipper', 'uuid': '1009'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Little Dipper',
#                                                           'uuid': '1009'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Little Dipper',
#                                                           'uuid': '1009'}}, stack=ImmutableStack(value={'parent_name': 'Dipstick'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'parent_name': 'Dipstick'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (41,
#   AdapterOperation(kind='yield', name='project_property', uid='008ae96c-cd45-4dc0-b251-4efb19395623', parent_uid='92457df4-8a82-4d06-a40b-f58effe075a4', data=(DataContext(current={'name': 'Little Dipper', 'uuid': '1009'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Little Dipper',
#                                                           'uuid': '1009'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Little Dipper',
#                                                           'uuid': '1009'}}, stack=ImmutableStack(value={'parent_name': 'Dipstick'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'parent_name': 'Dipstick'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Little Dipper'))),
#  (42,
#   AdapterOperation(kind='yield', name='__output_iterable_5', uid='0190a596-3c9e-416f-98c5-433803908ef8', parent_uid='1e735b33-c479-4c00-8c64-50da57c0996b', data={'name': 'Oddball', 'uuid': '1010'})),
#  (43,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='6f828b41-b1c2-4011-aadf-52a272d89146', parent_uid='42f1189d-8877-420a-99f3-4b40f17255a2', data=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Oddball',
#                                                           'uuid': '1010'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Oddball',
#                                                           'uuid': '1010'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (44,
#   AdapterOperation(kind='yield', name='project_property', uid='9f8e1c9a-c6bf-4e96-901c-dd3cd3aaf561', parent_uid='42f1189d-8877-420a-99f3-4b40f17255a2', data=(DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Oddball',
#                                                           'uuid': '1010'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Oddball',
#                                                           'uuid': '1010'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Dipstick'))),
#  (45,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='35fb7ad4-3bef-4f9a-b41d-2d608f342736', parent_uid='92457df4-8a82-4d06-a40b-f58effe075a4', data=DataContext(current={'name': 'Oddball', 'uuid': '1010'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Oddball',
#                                                           'uuid': '1010'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Oddball',
#                                                           'uuid': '1010'}}, stack=ImmutableStack(value={'parent_name': 'Dipstick'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'parent_name': 'Dipstick'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (46,
#   AdapterOperation(kind='yield', name='project_property', uid='efa486b9-2fec-4b1a-937d-d319969fd044', parent_uid='92457df4-8a82-4d06-a40b-f58effe075a4', data=(DataContext(current={'name': 'Oddball', 'uuid': '1010'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Oddball',
#                                                           'uuid': '1010'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dipstick', 'uuid': '1006'}, locations={Location(('Animal',), None, 1): {'name': 'Dipstick', 'uuid': '1006'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Oddball',
#                                                           'uuid': '1010'}}, stack=ImmutableStack(value={'parent_name': 'Dipstick'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'parent_name': 'Dipstick'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Oddball'))),
#  (47,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid='98f4906a-2a67-492b-99bc-9ece77f6ebad', parent_uid='a9a0f488-c926-4e07-afd1-a8b786285fc6', data={'name': 'Dottie', 'uuid': '1007'})),
#  (48,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='dd5d7ce3-780c-4be4-91c9-fc487861546f', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None))),
#  (49,
#   AdapterOperation(kind='yield', name='project_neighbors', uid='be006c13-0076-4196-ba66-85fbc4c3c535', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=(DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None), '__output_iterable_6'))),
#  (50,
#   AdapterOperation(kind='yield', name='__output_iterable_6', uid='c99b13bd-221b-4fb2-a916-3a3c536e2a40', parent_uid='be006c13-0076-4196-ba66-85fbc4c3c535', data={'name': 'Domino', 'uuid': '1008'})),
#  (51,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='22ba60d0-ccb1-4133-bdff-ad486ede0693', parent_uid='42f1189d-8877-420a-99f3-4b40f17255a2', data=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Domino',
#                                                           'uuid': '1008'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Domino',
#                                                           'uuid': '1008'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (52,
#   AdapterOperation(kind='yield', name='project_property', uid='420da720-8217-4d7f-b08e-b0ee2fa1e0f5', parent_uid='42f1189d-8877-420a-99f3-4b40f17255a2', data=(DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Domino',
#                                                           'uuid': '1008'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Domino',
#                                                           'uuid': '1008'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Dottie'))),
#  (53,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='82f62830-439a-4d7a-b0eb-cfb729332051', parent_uid='92457df4-8a82-4d06-a40b-f58effe075a4', data=DataContext(current={'name': 'Domino', 'uuid': '1008'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Domino',
#                                                           'uuid': '1008'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Domino',
#                                                           'uuid': '1008'}}, stack=ImmutableStack(value={'parent_name': 'Dottie'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'parent_name': 'Dottie'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (54,
#   AdapterOperation(kind='yield', name='project_property', uid='7a142b12-d022-425c-88d7-ebe51bdbb6e9', parent_uid='92457df4-8a82-4d06-a40b-f58effe075a4', data=(DataContext(current={'name': 'Domino', 'uuid': '1008'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Domino',
#                                                           'uuid': '1008'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Domino',
#                                                           'uuid': '1008'}}, stack=ImmutableStack(value={'parent_name': 'Dottie'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'parent_name': 'Dottie'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Domino'))),
#  (55,
#   AdapterOperation(kind='yield', name='__output_iterable_6', uid='b8beca58-0264-4b97-af2f-ebc22a4bce74', parent_uid='be006c13-0076-4196-ba66-85fbc4c3c535', data={'name': 'Little Dipper', 'uuid': '1009'})),
#  (56,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='0af149a2-343a-4d74-9f1d-cadabb919cff', parent_uid='42f1189d-8877-420a-99f3-4b40f17255a2', data=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Little Dipper',
#                                                           'uuid': '1009'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Little Dipper',
#                                                           'uuid': '1009'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (57,
#   AdapterOperation(kind='yield', name='project_property', uid='46566a9c-b3be-4406-bc65-cbe2e13c5a68', parent_uid='42f1189d-8877-420a-99f3-4b40f17255a2', data=(DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Little Dipper',
#                                                           'uuid': '1009'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Little Dipper',
#                                                           'uuid': '1009'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Dottie'))),
#  (58,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='5aae8c3b-c7d7-4666-99a2-e85e39cbd97e', parent_uid='92457df4-8a82-4d06-a40b-f58effe075a4', data=DataContext(current={'name': 'Little Dipper', 'uuid': '1009'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Little Dipper',
#                                                           'uuid': '1009'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Little Dipper',
#                                                           'uuid': '1009'}}, stack=ImmutableStack(value={'parent_name': 'Dottie'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'parent_name': 'Dottie'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (59,
#   AdapterOperation(kind='yield', name='project_property', uid='87246598-45e1-463b-bd5a-4e7f4766de0c', parent_uid='92457df4-8a82-4d06-a40b-f58effe075a4', data=(DataContext(current={'name': 'Little Dipper', 'uuid': '1009'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Little Dipper',
#                                                           'uuid': '1009'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Little Dipper',
#                                                           'uuid': '1009'}}, stack=ImmutableStack(value={'parent_name': 'Dottie'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'parent_name': 'Dottie'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Little Dipper'))),
#  (60,
#   AdapterOperation(kind='yield', name='__output_iterable_6', uid='c3bc892c-a6a3-423a-a544-03b86691e136', parent_uid='be006c13-0076-4196-ba66-85fbc4c3c535', data={'name': 'Oddball', 'uuid': '1010'})),
#  (61,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='8175f884-b491-422f-b587-1baf733be10d', parent_uid='42f1189d-8877-420a-99f3-4b40f17255a2', data=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Oddball',
#                                                           'uuid': '1010'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Oddball',
#                                                           'uuid': '1010'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (62,
#   AdapterOperation(kind='yield', name='project_property', uid='cc508fa6-fc9f-4aa9-b477-51802558fe9b', parent_uid='42f1189d-8877-420a-99f3-4b40f17255a2', data=(DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Oddball',
#                                                           'uuid': '1010'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Oddball',
#                                                           'uuid': '1010'}}, stack=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Dottie'))),
#  (63,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='be68205e-348c-4221-882b-3fe32ab4da39', parent_uid='92457df4-8a82-4d06-a40b-f58effe075a4', data=DataContext(current={'name': 'Oddball', 'uuid': '1010'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Oddball',
#                                                           'uuid': '1010'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Oddball',
#                                                           'uuid': '1010'}}, stack=ImmutableStack(value={'parent_name': 'Dottie'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'parent_name': 'Dottie'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None))),
#  (64,
#   AdapterOperation(kind='yield', name='project_property', uid='1d5c8088-f5be-4611-91b1-aa843b6d897b', parent_uid='92457df4-8a82-4d06-a40b-f58effe075a4', data=(DataContext(current={'name': 'Oddball', 'uuid': '1010'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Oddball',
#                                                           'uuid': '1010'}}, stack=ImmutableStack(value=DataContext(current={'name': 'Dottie', 'uuid': '1007'}, locations={Location(('Animal',), None, 1): {'name': 'Dottie', 'uuid': '1007'},
#    Location(('Animal', 'out_Animal_ParentOf'), None, 1): {'name': 'Oddball',
#                                                           'uuid': '1010'}}, stack=ImmutableStack(value={'parent_name': 'Dottie'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None)), piggyback=None), depth=2, tail=ImmutableStack(value={'parent_name': 'Dottie'}, depth=1, tail=ImmutableStack(value=None, depth=0, tail=None))), piggyback=None), 'Oddball'))),
#  (65,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid='441f777c-3060-4d9e-a67f-869d0c574e93', parent_uid='a9a0f488-c926-4e07-afd1-a8b786285fc6', data={'name': 'Domino', 'uuid': '1008'})),
#  (66,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='aea7fb8b-59f2-403f-a074-727de8f958de', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=DataContext(current={'name': 'Domino', 'uuid': '1008'}, locations={Location(('Animal',), None, 1): {'name': 'Domino', 'uuid': '1008'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None))),
#  (67,
#   AdapterOperation(kind='yield', name='project_neighbors', uid='0382012d-2a94-4b6f-a875-ba4e7129486f', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=(DataContext(current={'name': 'Domino', 'uuid': '1008'}, locations={Location(('Animal',), None, 1): {'name': 'Domino', 'uuid': '1008'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None), '__output_iterable_7'))),
#  (68,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid='a4968344-917e-44d0-94db-603e6a9931db', parent_uid='a9a0f488-c926-4e07-afd1-a8b786285fc6', data={'name': 'Little Dipper', 'uuid': '1009'})),
#  (69,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='96742529-33f6-499c-97f8-e952bf670163', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=DataContext(current={'name': 'Little Dipper', 'uuid': '1009'}, locations={Location(('Animal',), None, 1): {'name': 'Little Dipper', 'uuid': '1009'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None))),
#  (70,
#   AdapterOperation(kind='yield', name='project_neighbors', uid='6c7bb386-fbfa-490a-a335-957659479824', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=(DataContext(current={'name': 'Little Dipper', 'uuid': '1009'}, locations={Location(('Animal',), None, 1): {'name': 'Little Dipper', 'uuid': '1009'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None), '__output_iterable_8'))),
#  (71,
#   AdapterOperation(kind='yield', name='get_tokens_of_type', uid='faa2a4a8-a562-4b40-bc25-b60de4486cab', parent_uid='a9a0f488-c926-4e07-afd1-a8b786285fc6', data={'name': 'Oddball', 'uuid': '1010'})),
#  (72,
#   AdapterOperation(kind='yield', name='__input_iterable', uid='97bbfcda-47d1-41e4-b99c-ecf2eee35132', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=DataContext(current={'name': 'Oddball', 'uuid': '1010'}, locations={Location(('Animal',), None, 1): {'name': 'Oddball', 'uuid': '1010'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None))),
#  (73,
#   AdapterOperation(kind='yield', name='project_neighbors', uid='efbee860-2877-479c-8540-310a0951c2fe', parent_uid='242c61a3-f1f8-4403-ad9c-d3cdeaac015b', data=(DataContext(current={'name': 'Oddball', 'uuid': '1010'}, locations={Location(('Animal',), None, 1): {'name': 'Oddball', 'uuid': '1010'}}, stack=ImmutableStack(value=None, depth=0, tail=None), piggyback=None), '__output_iterable_9')))]

# %%
replay_adapter = TraceReplayAdapter(trace)

# %%
result_gen = interpret_ir(replay_adapter, ir_and_metadata, args)

# %%
list(result_gen)
# Out:
# [{'parent_name': 'Pongo', 'child_name': 'Dipstick'},
#  {'parent_name': 'Perdy', 'child_name': 'Dipstick'},
#  {'parent_name': 'Dipstick', 'child_name': 'Domino'},
#  {'parent_name': 'Dipstick', 'child_name': 'Little Dipper'},
#  {'parent_name': 'Dipstick', 'child_name': 'Oddball'},
#  {'parent_name': 'Dottie', 'child_name': 'Domino'},
#  {'parent_name': 'Dottie', 'child_name': 'Little Dipper'},
#  {'parent_name': 'Dottie', 'child_name': 'Oddball'}]
